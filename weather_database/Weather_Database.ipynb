# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(low = -180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 759

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval    ")
print("----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# ----------------------------

# %%
# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 ==0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(5)
        
     # Create endpoint URL with each city.   
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count +=1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_info = city_weather["weather"][0]["description"]

        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime("%Y-%m-%d %H:%M:%S")
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                         "Current Weather Description" : city_weather_info})
                       
        
# If an error is experienced, skip the city.  
    except:
        print("City not found. Skipping....")
        pass
# Indicate that Data Loading is complete.
print("----------------------------------")
print("Data Retrieval Complete...........")
print("----------------------------------")
# Out:
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping....
# Processing Record 3 of Set 1 | northam
# Processing Record 4 of Set 1 | vaitupu
# City not found. Skipping....
# Processing Record 5 of Set 1 | bambous virieux
# Processing Record 6 of Set 1 | metro
# Processing Record 7 of Set 1 | ponta do sol
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | beloha
# Processing Record 10 of Set 1 | butaritari
# Processing Record 11 of Set 1 | grand river south east
# City not found. Skipping....
# Processing Record 12 of Set 1 | lodwar
# Processing Record 13 of Set 1 | puerto ayora
# Processing Record 14 of Set 1 | namibe
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | ribeira grande
# Processing Record 17 of Set 1 | mar del plata
# Processing Record 18 of Set 1 | tiznit
# Processing Record 19 of Set 1 | cabo san lucas
# Processing Record 20 of Set 1 | avarua
# Processing Record 21 of Set 1 | caravelas
# Processing Record 22 of Set 1 | queimadas
# Processing Record 23 of Set 1 | eyl
# Processing Record 24 of Set 1 | arraial do cabo
# Processing Record 25 of Set 1 | tuktoyaktuk
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | port elizabeth
# Processing Record 28 of Set 1 | nguiu
# City not found. Skipping....
# Processing Record 29 of Set 1 | saint-augustin
# Processing Record 30 of Set 1 | barrow
# Processing Record 31 of Set 1 | khorramshahr
# Processing Record 32 of Set 1 | cairns
# Processing Record 33 of Set 1 | watertown
# Processing Record 34 of Set 1 | cape town
# Processing Record 35 of Set 1 | karmala
# Processing Record 36 of Set 1 | srednekolymsk
# Processing Record 37 of Set 1 | punta arenas
# Processing Record 38 of Set 1 | clyde river
# Processing Record 39 of Set 1 | esperance
# Processing Record 40 of Set 1 | san patricio
# Processing Record 41 of Set 1 | udachnyy
# Processing Record 42 of Set 1 | port alfred
# Processing Record 43 of Set 1 | upernavik
# Processing Record 44 of Set 1 | nikolskoye
# Processing Record 45 of Set 1 | qaanaaq
# Processing Record 46 of Set 1 | tsihombe
# City not found. Skipping....
# Processing Record 47 of Set 1 | wuwei
# Processing Record 48 of Set 1 | ixtapa
# Processing Record 49 of Set 1 | tabiauea
# City not found. Skipping....
# Processing Record 50 of Set 1 | poum
# Processing Record 1 of Set 2 | abha
# Processing Record 2 of Set 2 | itarema
# Processing Record 3 of Set 2 | nizhneyansk
# City not found. Skipping....
# Processing Record 4 of Set 2 | yellowknife
# Processing Record 5 of Set 2 | saskylakh
# Processing Record 6 of Set 2 | saint-philippe
# Processing Record 7 of Set 2 | sao joao da barra
# Processing Record 8 of Set 2 | bar harbor
# Processing Record 9 of Set 2 | upington
# Processing Record 10 of Set 2 | georgetown
# Processing Record 11 of Set 2 | flinders
# Processing Record 12 of Set 2 | kapaa
# Processing Record 13 of Set 2 | camana
# Processing Record 14 of Set 2 | hobart
# Processing Record 15 of Set 2 | iqaluit
# Processing Record 16 of Set 2 | palabuhanratu
# City not found. Skipping....
# Processing Record 17 of Set 2 | tasiilaq
# Processing Record 18 of Set 2 | troitsko-pechorsk
# Processing Record 19 of Set 2 | kyra
# Processing Record 20 of Set 2 | hasaki
# Processing Record 21 of Set 2 | bluff
# Processing Record 22 of Set 2 | ferkessedougou
# Processing Record 23 of Set 2 | portland
# Processing Record 24 of Set 2 | port lincoln
# Processing Record 25 of Set 2 | ekibastuz
# Processing Record 26 of Set 2 | cradock
# Processing Record 27 of Set 2 | kingsland
# Processing Record 28 of Set 2 | khandyga
# Processing Record 29 of Set 2 | malanje
# Processing Record 30 of Set 2 | mataura
# Processing Record 31 of Set 2 | bodden town
# Processing Record 32 of Set 2 | vaini
# Processing Record 33 of Set 2 | mahebourg
# Processing Record 34 of Set 2 | dikson
# Processing Record 35 of Set 2 | santa eulalia del rio
# City not found. Skipping....
# Processing Record 36 of Set 2 | carnarvon
# Processing Record 37 of Set 2 | chapais
# Processing Record 38 of Set 2 | vallenar
# Processing Record 39 of Set 2 | kapoeta
# Processing Record 40 of Set 2 | east hampton
# Processing Record 41 of Set 2 | iracoubo
# Processing Record 42 of Set 2 | busselton
# Processing Record 43 of Set 2 | fortuna
# Processing Record 44 of Set 2 | pangnirtung
# Processing Record 45 of Set 2 | faanui
# Processing Record 46 of Set 2 | guerrero negro
# Processing Record 47 of Set 2 | libertador general san martin
# Processing Record 48 of Set 2 | college
# Processing Record 49 of Set 2 | karakol
# Processing Record 50 of Set 2 | paamiut
# Processing Record 1 of Set 3 | ayagoz
# Processing Record 2 of Set 3 | nanortalik
# Processing Record 3 of Set 3 | owando
# Processing Record 4 of Set 3 | jamestown
# Processing Record 5 of Set 3 | dingle
# Processing Record 6 of Set 3 | ulladulla
# Processing Record 7 of Set 3 | bredasdorp
# Processing Record 8 of Set 3 | tura
# Processing Record 9 of Set 3 | provideniya
# Processing Record 10 of Set 3 | tukrah
# Processing Record 11 of Set 3 | new norfolk
# Processing Record 12 of Set 3 | east london
# Processing Record 13 of Set 3 | dunedin
# Processing Record 14 of Set 3 | bandarbeyla
# Processing Record 15 of Set 3 | meadow lake
# Processing Record 16 of Set 3 | airai
# Processing Record 17 of Set 3 | skjervoy
# Processing Record 18 of Set 3 | ankpa
# Processing Record 19 of Set 3 | lavrentiya
# Processing Record 20 of Set 3 | egvekinot
# Processing Record 21 of Set 3 | castro
# Processing Record 22 of Set 3 | khatanga
# Processing Record 23 of Set 3 | illoqqortoormiut
# City not found. Skipping....
# Processing Record 24 of Set 3 | kiama
# Processing Record 25 of Set 3 | maniitsoq
# Processing Record 26 of Set 3 | kruisfontein
# Processing Record 27 of Set 3 | praya
# Processing Record 28 of Set 3 | marcona
# City not found. Skipping....
# Processing Record 29 of Set 3 | ziro
# Processing Record 30 of Set 3 | high level
# Processing Record 31 of Set 3 | mangan
# Processing Record 32 of Set 3 | korla
# Processing Record 33 of Set 3 | hvide sande
# Processing Record 34 of Set 3 | tessalit
# Processing Record 35 of Set 3 | mys shmidta
# City not found. Skipping....
# Processing Record 36 of Set 3 | russell
# Processing Record 37 of Set 3 | lamu
# Processing Record 38 of Set 3 | chudovo
# Processing Record 39 of Set 3 | finschhafen
# Processing Record 40 of Set 3 | nouadhibou
# Processing Record 41 of Set 3 | villa maria
# Processing Record 42 of Set 3 | chokurdakh
# Processing Record 43 of Set 3 | saint george
# Processing Record 44 of Set 3 | lunglei
# Processing Record 45 of Set 3 | komsomolskiy
# Processing Record 46 of Set 3 | hilo
# Processing Record 47 of Set 3 | severo-kurilsk
# Processing Record 48 of Set 3 | zverinogolovskoye
# Processing Record 49 of Set 3 | graaff-reinet
# Processing Record 50 of Set 3 | marzuq
# Processing Record 1 of Set 4 | mungaa
# Processing Record 2 of Set 4 | melnikovo
# Processing Record 3 of Set 4 | rocha
# Processing Record 4 of Set 4 | salalah
# Processing Record 5 of Set 4 | joao neiva
# Processing Record 6 of Set 4 | shaoxing
# Processing Record 7 of Set 4 | jarjis
# City not found. Skipping....
# Processing Record 8 of Set 4 | kodiak
# Processing Record 9 of Set 4 | broken hill
# Processing Record 10 of Set 4 | villa carlos paz
# Processing Record 11 of Set 4 | rio grande
# Processing Record 12 of Set 4 | kavieng
# Processing Record 13 of Set 4 | nabha
# Processing Record 14 of Set 4 | odweyne
# Processing Record 15 of Set 4 | attawapiskat
# City not found. Skipping....
# Processing Record 16 of Set 4 | kaitangata
# Processing Record 17 of Set 4 | xingyi
# Processing Record 18 of Set 4 | lorengau
# Processing Record 19 of Set 4 | puerto colombia
# Processing Record 20 of Set 4 | margate
# Processing Record 21 of Set 4 | jumla
# Processing Record 22 of Set 4 | atuona
# Processing Record 23 of Set 4 | katsuura
# Processing Record 24 of Set 4 | alihe
# Processing Record 25 of Set 4 | lompoc
# Processing Record 26 of Set 4 | zhizdra
# Processing Record 27 of Set 4 | robertsport
# Processing Record 28 of Set 4 | krasnoselkup
# Processing Record 29 of Set 4 | longyearbyen
# Processing Record 30 of Set 4 | pisco
# Processing Record 31 of Set 4 | tilichiki
# Processing Record 32 of Set 4 | aklavik
# Processing Record 33 of Set 4 | phuket
# Processing Record 34 of Set 4 | stornoway
# Processing Record 35 of Set 4 | samalaeulu
# City not found. Skipping....
# Processing Record 36 of Set 4 | goderich
# Processing Record 37 of Set 4 | cidreira
# Processing Record 38 of Set 4 | sri aman
# Processing Record 39 of Set 4 | praia
# Processing Record 40 of Set 4 | tiksi
# Processing Record 41 of Set 4 | coquimbo
# Processing Record 42 of Set 4 | narsaq
# Processing Record 43 of Set 4 | sataua
# City not found. Skipping....
# Processing Record 44 of Set 4 | thompson
# Processing Record 45 of Set 4 | payo
# Processing Record 46 of Set 4 | alice springs
# Processing Record 47 of Set 4 | mirnyy
# Processing Record 48 of Set 4 | rovaniemi
# Processing Record 49 of Set 4 | barentsburg
# City not found. Skipping....
# Processing Record 50 of Set 4 | klaksvik
# Processing Record 1 of Set 5 | campos altos
# Processing Record 2 of Set 5 | patacamaya
# Processing Record 3 of Set 5 | andenes
# Processing Record 4 of Set 5 | bireun
# Processing Record 5 of Set 5 | uvelskiy
# Processing Record 6 of Set 5 | bushehr
# Processing Record 7 of Set 5 | andzhiyevskiy
# Processing Record 8 of Set 5 | madruga
# Processing Record 9 of Set 5 | pocone
# Processing Record 10 of Set 5 | biak
# Processing Record 11 of Set 5 | ancud
# Processing Record 12 of Set 5 | osoyoos
# Processing Record 13 of Set 5 | katherine
# Processing Record 14 of Set 5 | norman wells
# Processing Record 15 of Set 5 | richards bay
# Processing Record 16 of Set 5 | muros
# Processing Record 17 of Set 5 | eha amufu
# Processing Record 18 of Set 5 | inderborskiy
# City not found. Skipping....
# Processing Record 19 of Set 5 | deputatskiy
# Processing Record 20 of Set 5 | victoria
# Processing Record 21 of Set 5 | havre-saint-pierre
# Processing Record 22 of Set 5 | zonguldak
# Processing Record 23 of Set 5 | yialos
# City not found. Skipping....
# Processing Record 24 of Set 5 | arlit
# Processing Record 25 of Set 5 | vardo
# Processing Record 26 of Set 5 | cockburn town
# Processing Record 27 of Set 5 | shima
# Processing Record 28 of Set 5 | souillac
# Processing Record 29 of Set 5 | agua verde
# Processing Record 30 of Set 5 | ahipara
# Processing Record 31 of Set 5 | bousso
# Processing Record 32 of Set 5 | tromso
# Processing Record 33 of Set 5 | atikokan
# Processing Record 34 of Set 5 | sol-iletsk
# Processing Record 35 of Set 5 | touros
# Processing Record 36 of Set 5 | trincomalee
# Processing Record 37 of Set 5 | kiunga
# Processing Record 38 of Set 5 | abu dhabi
# Processing Record 39 of Set 5 | amderma
# City not found. Skipping....
# Processing Record 40 of Set 5 | bilma
# Processing Record 41 of Set 5 | port hardy
# Processing Record 42 of Set 5 | neryungri
# Processing Record 43 of Set 5 | jahrom
# City not found. Skipping....
# Processing Record 44 of Set 5 | jabinyanah
# Processing Record 45 of Set 5 | chuy
# Processing Record 46 of Set 5 | bako
# Processing Record 47 of Set 5 | hithadhoo
# Processing Record 48 of Set 5 | tecoanapa
# Processing Record 49 of Set 5 | porto walter
# Processing Record 50 of Set 5 | pauini
# Processing Record 1 of Set 6 | belushya guba
# City not found. Skipping....
# Processing Record 2 of Set 6 | sentyabrskiy
# City not found. Skipping....
# Processing Record 3 of Set 6 | lakselv
# Processing Record 4 of Set 6 | calabozo
# Processing Record 5 of Set 6 | vanimo
# Processing Record 6 of Set 6 | matrei
# City not found. Skipping....
# Processing Record 7 of Set 6 | fort nelson
# Processing Record 8 of Set 6 | gazanjyk
# Processing Record 9 of Set 6 | alofi
# Processing Record 10 of Set 6 | utiroa
# City not found. Skipping....
# Processing Record 11 of Set 6 | vila franca do campo
# Processing Record 12 of Set 6 | vostok
# Processing Record 13 of Set 6 | novokizhinginsk
# Processing Record 14 of Set 6 | lolua
# City not found. Skipping....
# Processing Record 15 of Set 6 | saldanha
# Processing Record 16 of Set 6 | bemidji
# Processing Record 17 of Set 6 | afua
# Processing Record 18 of Set 6 | ziniare
# Processing Record 19 of Set 6 | laguna
# Processing Record 20 of Set 6 | reinosa
# Processing Record 21 of Set 6 | slonim
# Processing Record 22 of Set 6 | harper
# Processing Record 23 of Set 6 | los llanos de aridane
# Processing Record 24 of Set 6 | suket
# Processing Record 25 of Set 6 | pruszkow
# Processing Record 26 of Set 6 | puerto leguizamo
# Processing Record 27 of Set 6 | rio das ostras
# Processing Record 28 of Set 6 | warqla
# City not found. Skipping....
# Processing Record 29 of Set 6 | lebu
# Processing Record 30 of Set 6 | belgrade
# Processing Record 31 of Set 6 | umzimvubu
# City not found. Skipping....
# Processing Record 32 of Set 6 | naze
# Processing Record 33 of Set 6 | san ramon
# Processing Record 34 of Set 6 | bani walid
# Processing Record 35 of Set 6 | bathsheba
# Processing Record 36 of Set 6 | kieta
# Processing Record 37 of Set 6 | huarmey
# Processing Record 38 of Set 6 | solnechnyy
# Processing Record 39 of Set 6 | tuatapere
# Processing Record 40 of Set 6 | bengkulu
# Processing Record 41 of Set 6 | gurupi
# Processing Record 42 of Set 6 | cherskiy
# Processing Record 43 of Set 6 | ambilobe
# Processing Record 44 of Set 6 | santa cruz
# Processing Record 45 of Set 6 | yumen
# Processing Record 46 of Set 6 | saint anthony
# Processing Record 47 of Set 6 | yelnya
# Processing Record 48 of Set 6 | vanavara
# Processing Record 49 of Set 6 | acarau
# Processing Record 50 of Set 6 | samarai
# Processing Record 1 of Set 7 | pacific grove
# Processing Record 2 of Set 7 | taoudenni
# Processing Record 3 of Set 7 | mkushi
# Processing Record 4 of Set 7 | oranjestad
# Processing Record 5 of Set 7 | kichmengskiy gorodok
# Processing Record 6 of Set 7 | linqiong
# Processing Record 7 of Set 7 | codrington
# Processing Record 8 of Set 7 | cap malheureux
# Processing Record 9 of Set 7 | anadyr
# Processing Record 10 of Set 7 | carutapera
# Processing Record 11 of Set 7 | mogochin
# City not found. Skipping....
# Processing Record 12 of Set 7 | yar-sale
# Processing Record 13 of Set 7 | tautira
# Processing Record 14 of Set 7 | san jose
# Processing Record 15 of Set 7 | nome
# Processing Record 16 of Set 7 | longlac
# City not found. Skipping....
# Processing Record 17 of Set 7 | grindavik
# Processing Record 18 of Set 7 | banikoara
# Processing Record 19 of Set 7 | manati
# Processing Record 20 of Set 7 | sitka
# Processing Record 21 of Set 7 | sakakah
# Processing Record 22 of Set 7 | bereda
# Processing Record 23 of Set 7 | poronaysk
# Processing Record 24 of Set 7 | ust-kulom
# Processing Record 25 of Set 7 | banda aceh
# Processing Record 26 of Set 7 | yerbogachen
# Processing Record 27 of Set 7 | puerto ayacucho
# Processing Record 28 of Set 7 | ukiah
# Processing Record 29 of Set 7 | nizwa
# Processing Record 30 of Set 7 | flin flon
# Processing Record 31 of Set 7 | lata
# Processing Record 32 of Set 7 | wanderlandia
# City not found. Skipping....
# Processing Record 33 of Set 7 | bara
# Processing Record 34 of Set 7 | umm lajj
# Processing Record 35 of Set 7 | ndele
# Processing Record 36 of Set 7 | matveyev kurgan
# Processing Record 37 of Set 7 | xining
# Processing Record 38 of Set 7 | malangali
# Processing Record 39 of Set 7 | mogadishu
# Processing Record 40 of Set 7 | virginia beach
# Processing Record 41 of Set 7 | premia de mar
# Processing Record 42 of Set 7 | half moon bay
# Processing Record 43 of Set 7 | cervo
# Processing Record 44 of Set 7 | grand-santi
# Processing Record 45 of Set 7 | azimur
# City not found. Skipping....
# Processing Record 46 of Set 7 | seymchan
# Processing Record 47 of Set 7 | amapa
# Processing Record 48 of Set 7 | talnakh
# Processing Record 49 of Set 7 | dharmanagar
# Processing Record 50 of Set 7 | kudahuvadhoo
# Processing Record 1 of Set 8 | coahuayana
# Processing Record 2 of Set 8 | hirara
# Processing Record 3 of Set 8 | doka
# Processing Record 4 of Set 8 | bani
# Processing Record 5 of Set 8 | pendleton
# Processing Record 6 of Set 8 | vila
# Processing Record 7 of Set 8 | quatre cocos
# Processing Record 8 of Set 8 | norsup
# Processing Record 9 of Set 8 | borazjan
# Processing Record 10 of Set 8 | pietarsaari
# Processing Record 11 of Set 8 | nyurba
# Processing Record 12 of Set 8 | sao filipe
# Processing Record 13 of Set 8 | la ronge
# Processing Record 14 of Set 8 | general roca
# Processing Record 15 of Set 8 | khani
# Processing Record 16 of Set 8 | hamilton
# Processing Record 17 of Set 8 | avanigadda
# Processing Record 18 of Set 8 | nishihara
# Processing Record 19 of Set 8 | verkhnyaya inta
# Processing Record 20 of Set 8 | marawi
# Processing Record 21 of Set 8 | nagato
# Processing Record 22 of Set 8 | taguatinga
# Processing Record 23 of Set 8 | stromness
# Processing Record 24 of Set 8 | torbay
# Processing Record 25 of Set 8 | zyryanovsk
# Processing Record 26 of Set 8 | taybad
# Processing Record 27 of Set 8 | ishinomaki
# Processing Record 28 of Set 8 | jablah
# Processing Record 29 of Set 8 | micheweni
# Processing Record 30 of Set 8 | tevriz
# Processing Record 31 of Set 8 | mildura
# Processing Record 32 of Set 8 | byron bay
# Processing Record 33 of Set 8 | tupik
# Processing Record 34 of Set 8 | ilulissat
# Processing Record 35 of Set 8 | yulara
# Processing Record 36 of Set 8 | viedma
# Processing Record 37 of Set 8 | vao
# Processing Record 38 of Set 8 | inhambane
# Processing Record 39 of Set 8 | leningradskiy
# Processing Record 40 of Set 8 | durres
# Processing Record 41 of Set 8 | verkhoyansk
# Processing Record 42 of Set 8 | bethel
# Processing Record 43 of Set 8 | gamba
# Processing Record 44 of Set 8 | saint-pierre
# Processing Record 45 of Set 8 | garowe
# Processing Record 46 of Set 8 | faridpur
# Processing Record 47 of Set 8 | nuuk
# Processing Record 48 of Set 8 | bonavista
# Processing Record 49 of Set 8 | ankara
# Processing Record 50 of Set 8 | visby
# Processing Record 1 of Set 9 | solovetskiy
# City not found. Skipping....
# Processing Record 2 of Set 9 | emerald
# Processing Record 3 of Set 9 | todos santos
# Processing Record 4 of Set 9 | san cristobal
# Processing Record 5 of Set 9 | laiagam
# City not found. Skipping....
# Processing Record 6 of Set 9 | sorland
# Processing Record 7 of Set 9 | wonthaggi
# Processing Record 8 of Set 9 | ankazoabo
# Processing Record 9 of Set 9 | thinadhoo
# Processing Record 10 of Set 9 | palmas
# Processing Record 11 of Set 9 | mount isa
# Processing Record 12 of Set 9 | mayo
# Processing Record 13 of Set 9 | gejiu
# Processing Record 14 of Set 9 | aldama
# Processing Record 15 of Set 9 | saint-louis
# Processing Record 16 of Set 9 | bonfim
# Processing Record 17 of Set 9 | mumford
# Processing Record 18 of Set 9 | corum
# Processing Record 19 of Set 9 | mehamn
# Processing Record 20 of Set 9 | auki
# Processing Record 21 of Set 9 | tierralta
# Processing Record 22 of Set 9 | satitoa
# City not found. Skipping....
# Processing Record 23 of Set 9 | saleaula
# City not found. Skipping....
# Processing Record 24 of Set 9 | saint hubert
# Processing Record 25 of Set 9 | manta
# Processing Record 26 of Set 9 | gillette
# Processing Record 27 of Set 9 | gizo
# Processing Record 28 of Set 9 | coos bay
# Processing Record 29 of Set 9 | vestmannaeyjar
# Processing Record 30 of Set 9 | horodnytsya
# Processing Record 31 of Set 9 | zhezkazgan
# Processing Record 32 of Set 9 | labuhan
# Processing Record 33 of Set 9 | salina
# Processing Record 34 of Set 9 | seoul
# Processing Record 35 of Set 9 | sanchor
# Processing Record 36 of Set 9 | mahanoro
# Processing Record 37 of Set 9 | kingsville
# Processing Record 38 of Set 9 | alto paraguai
# Processing Record 39 of Set 9 | tabas
# Processing Record 40 of Set 9 | ishigaki
# Processing Record 41 of Set 9 | pokhara
# Processing Record 42 of Set 9 | tabou
# Processing Record 43 of Set 9 | ihiala
# Processing Record 44 of Set 9 | ust-ishim
# Processing Record 45 of Set 9 | jomalig
# City not found. Skipping....
# Processing Record 46 of Set 9 | honiara
# Processing Record 47 of Set 9 | viksoyri
# City not found. Skipping....
# Processing Record 48 of Set 9 | karaul
# City not found. Skipping....
# Processing Record 49 of Set 9 | kamenskoye
# City not found. Skipping....
# Processing Record 50 of Set 9 | tomatlan
# Processing Record 1 of Set 10 | grand gaube
# Processing Record 2 of Set 10 | linxia
# Processing Record 3 of Set 10 | maykain
# City not found. Skipping....
# Processing Record 4 of Set 10 | bilibino
# Processing Record 5 of Set 10 | kaeo
# Processing Record 6 of Set 10 | ibra
# Processing Record 7 of Set 10 | kulhudhuffushi
# Processing Record 8 of Set 10 | kamaishi
# Processing Record 9 of Set 10 | gravdal
# Processing Record 10 of Set 10 | felnac
# Processing Record 11 of Set 10 | yetholm
# City not found. Skipping....
# Processing Record 12 of Set 10 | cheyenne
# Processing Record 13 of Set 10 | kidal
# Processing Record 14 of Set 10 | okhotsk
# Processing Record 15 of Set 10 | sunndalsora
# Processing Record 16 of Set 10 | mandalgovi
# Processing Record 17 of Set 10 | kirensk
# Processing Record 18 of Set 10 | pop
# Processing Record 19 of Set 10 | ati
# Processing Record 20 of Set 10 | alyangula
# Processing Record 21 of Set 10 | novikovo
# Processing Record 22 of Set 10 | anju
# Processing Record 23 of Set 10 | teguldet
# Processing Record 24 of Set 10 | yebaishou
# Processing Record 25 of Set 10 | juneau
# Processing Record 26 of Set 10 | damavand
# Processing Record 27 of Set 10 | saint-francois
# Processing Record 28 of Set 10 | westport
# Processing Record 29 of Set 10 | palmer
# Processing Record 30 of Set 10 | one hundred mile house
# City not found. Skipping....
# Processing Record 31 of Set 10 | araguaina
# Processing Record 32 of Set 10 | orbetello
# Processing Record 33 of Set 10 | tripoli
# Processing Record 34 of Set 10 | aksu
# Processing Record 35 of Set 10 | canico
# Processing Record 36 of Set 10 | darnah
# Processing Record 37 of Set 10 | saint-alexandre
# Processing Record 38 of Set 10 | puerto baquerizo moreno
# Processing Record 39 of Set 10 | san joaquin
# Processing Record 40 of Set 10 | vila velha
# Processing Record 41 of Set 10 | batemans bay
# Processing Record 42 of Set 10 | acapulco
# Processing Record 43 of Set 10 | samusu
# City not found. Skipping....
# Processing Record 44 of Set 10 | ambon
# Processing Record 45 of Set 10 | foshan
# Processing Record 46 of Set 10 | dongsheng
# Processing Record 47 of Set 10 | mamakan
# Processing Record 48 of Set 10 | karkaralinsk
# City not found. Skipping....
# Processing Record 49 of Set 10 | igrim
# Processing Record 50 of Set 10 | leczna
# Processing Record 1 of Set 11 | isangel
# Processing Record 2 of Set 11 | atbasar
# Processing Record 3 of Set 11 | nemuro
# Processing Record 4 of Set 11 | belaya gora
# Processing Record 5 of Set 11 | kambove
# Processing Record 6 of Set 11 | balabac
# Processing Record 7 of Set 11 | waddan
# Processing Record 8 of Set 11 | port blair
# Processing Record 9 of Set 11 | quzhou
# Processing Record 10 of Set 11 | hualmay
# Processing Record 11 of Set 11 | wajima
# Processing Record 12 of Set 11 | kargasok
# Processing Record 13 of Set 11 | turtkul
# City not found. Skipping....
# Processing Record 14 of Set 11 | cayenne
# Processing Record 15 of Set 11 | crab hill
# City not found. Skipping....
# Processing Record 16 of Set 11 | baruun-urt
# Processing Record 17 of Set 11 | akcakoca
# Processing Record 18 of Set 11 | sinnamary
# Processing Record 19 of Set 11 | lubbock
# Processing Record 20 of Set 11 | isla mujeres
# Processing Record 21 of Set 11 | sola
# Processing Record 22 of Set 11 | myitkyina
# Processing Record 23 of Set 11 | cienfuegos
# Processing Record 24 of Set 11 | santa catalina
# Processing Record 25 of Set 11 | coihaique
# Processing Record 26 of Set 11 | chifeng
# Processing Record 27 of Set 11 | faya
# Processing Record 28 of Set 11 | mattru
# Processing Record 29 of Set 11 | boca do acre
# Processing Record 30 of Set 11 | andapa
# Processing Record 31 of Set 11 | areosa
# Processing Record 32 of Set 11 | pokaran
# Processing Record 33 of Set 11 | tubuala
# Processing Record 34 of Set 11 | akrata
# Processing Record 35 of Set 11 | guayaramerin
# Processing Record 36 of Set 11 | naryan-mar
# Processing Record 37 of Set 11 | antissa
# City not found. Skipping....
# Processing Record 38 of Set 11 | ostrovnoy
# Processing Record 39 of Set 11 | pochutla
# Processing Record 40 of Set 11 | general artigas
# Processing Record 41 of Set 11 | teya
# Processing Record 42 of Set 11 | qingdao
# Processing Record 43 of Set 11 | sao miguel
# Processing Record 44 of Set 11 | cheyur
# City not found. Skipping....
# Processing Record 45 of Set 11 | waipawa
# Processing Record 46 of Set 11 | north bend
# Processing Record 47 of Set 11 | iranshahr
# Processing Record 48 of Set 11 | vigrestad
# Processing Record 49 of Set 11 | chara
# Processing Record 50 of Set 11 | baoqing
# Processing Record 1 of Set 12 | basoko
# Processing Record 2 of Set 12 | yirol
# City not found. Skipping....
# Processing Record 3 of Set 12 | hay river
# Processing Record 4 of Set 12 | lagoa
# Processing Record 5 of Set 12 | san quintin
# Processing Record 6 of Set 12 | makuyuni
# Processing Record 7 of Set 12 | jiwani
# Processing Record 8 of Set 12 | sao luiz gonzaga
# Processing Record 9 of Set 12 | barcelos
# Processing Record 10 of Set 12 | luau
# Processing Record 11 of Set 12 | mana
# Processing Record 12 of Set 12 | santa rosa
# Processing Record 13 of Set 12 | vredendal
# Processing Record 14 of Set 12 | pontianak
# Processing Record 15 of Set 12 | kavaratti
# Processing Record 16 of Set 12 | pasni
# Processing Record 17 of Set 12 | sabzevar
# Processing Record 18 of Set 12 | mazulskiy
# City not found. Skipping....
# Processing Record 19 of Set 12 | langsa
# Processing Record 20 of Set 12 | maku
# Processing Record 21 of Set 12 | bati
# Processing Record 22 of Set 12 | beausejour
# Processing Record 23 of Set 12 | donskoye
# Processing Record 24 of Set 12 | vung tau
# Processing Record 25 of Set 12 | powell river
# Processing Record 26 of Set 12 | torit
# Processing Record 27 of Set 12 | kampong thum
# Processing Record 28 of Set 12 | sur
# Processing Record 29 of Set 12 | cabedelo
# Processing Record 30 of Set 12 | port-gentil
# Processing Record 31 of Set 12 | buqayq
# City not found. Skipping....
# Processing Record 32 of Set 12 | juxtlahuaca
# Processing Record 33 of Set 12 | doctor arroyo
# Processing Record 34 of Set 12 | maturin
# Processing Record 35 of Set 12 | azanka
# Processing Record 36 of Set 12 | bintulu
# Processing Record 37 of Set 12 | astipalaia
# City not found. Skipping....
# Processing Record 38 of Set 12 | morondava
# Processing Record 39 of Set 12 | narrabri
# Processing Record 40 of Set 12 | ahlat
# Processing Record 41 of Set 12 | beira
# Processing Record 42 of Set 12 | umm durman
# City not found. Skipping....
# Processing Record 43 of Set 12 | ikom
# Processing Record 44 of Set 12 | taraza
# Processing Record 45 of Set 12 | kutum
# Processing Record 46 of Set 12 | wangkui
# Processing Record 47 of Set 12 | ahuimanu
# Processing Record 48 of Set 12 | pueblo nuevo
# Processing Record 49 of Set 12 | mafinga
# Processing Record 50 of Set 12 | gat
# Processing Record 1 of Set 13 | jashpurnagar
# Processing Record 2 of Set 13 | afmadu
# City not found. Skipping....
# Processing Record 3 of Set 13 | luderitz
# Processing Record 4 of Set 13 | boguchany
# Processing Record 5 of Set 13 | fukue
# Processing Record 6 of Set 13 | mae hong son
# Processing Record 7 of Set 13 | axim
# Processing Record 8 of Set 13 | abu kamal
# Processing Record 9 of Set 13 | ornskoldsvik
# Processing Record 10 of Set 13 | tahoua
# Processing Record 11 of Set 13 | concarneau
# Processing Record 12 of Set 13 | nokha
# Processing Record 13 of Set 13 | capellania
# Processing Record 14 of Set 13 | kachug
# Processing Record 15 of Set 13 | sobolevo
# Processing Record 16 of Set 13 | masvingo
# Processing Record 17 of Set 13 | sayat
# Processing Record 18 of Set 13 | ascope
# Processing Record 19 of Set 13 | castelldefels
# Processing Record 20 of Set 13 | pitkyaranta
# Processing Record 21 of Set 13 | meulaboh
# Processing Record 22 of Set 13 | mahajanga
# Processing Record 23 of Set 13 | tidore
# City not found. Skipping....
# Processing Record 24 of Set 13 | asau
# Processing Record 25 of Set 13 | los palacios
# Processing Record 26 of Set 13 | pringsewu
# Processing Record 27 of Set 13 | marsaxlokk
# Processing Record 28 of Set 13 | shingu
# Processing Record 29 of Set 13 | dire dawa
# Processing Record 30 of Set 13 | davila
# Processing Record 31 of Set 13 | karratha
# Processing Record 32 of Set 13 | mitsamiouli
# Processing Record 33 of Set 13 | broome
# Processing Record 34 of Set 13 | bosaso
# Processing Record 35 of Set 13 | haines junction
# Processing Record 36 of Set 13 | duldurga
# Processing Record 37 of Set 13 | khash
# Processing Record 38 of Set 13 | kaka
# Processing Record 39 of Set 13 | belyy yar
# Processing Record 40 of Set 13 | borinskoye
# Processing Record 41 of Set 13 | moron
# Processing Record 42 of Set 13 | boyolangu
# Processing Record 43 of Set 13 | naftah
# City not found. Skipping....
# Processing Record 44 of Set 13 | sao jose da coroa grande
# Processing Record 45 of Set 13 | aketi
# Processing Record 46 of Set 13 | bin qirdan
# Processing Record 47 of Set 13 | gangotri
# City not found. Skipping....
# Processing Record 48 of Set 13 | karabash
# Processing Record 49 of Set 13 | alappuzha
# Processing Record 50 of Set 13 | koslan
# Processing Record 1 of Set 14 | aswan
# Processing Record 2 of Set 14 | walvis bay
# Processing Record 3 of Set 14 | tawkar
# City not found. Skipping....
# Processing Record 4 of Set 14 | louisbourg
# City not found. Skipping....
# Processing Record 5 of Set 14 | pevek
# Processing Record 6 of Set 14 | san jeronimo
# Processing Record 7 of Set 14 | olafsvik
# Processing Record 8 of Set 14 | aykhal
# Processing Record 9 of Set 14 | capitan bado
# Processing Record 10 of Set 14 | jilmah
# City not found. Skipping....
# Processing Record 11 of Set 14 | san miguel
# Processing Record 12 of Set 14 | bagdarin
# Processing Record 13 of Set 14 | voznesenye
# Processing Record 14 of Set 14 | trelew
# Processing Record 15 of Set 14 | tezu
# Processing Record 16 of Set 14 | conceicao do araguaia
# Processing Record 17 of Set 14 | rudbar
# Processing Record 18 of Set 14 | umm kaddadah
# Processing Record 19 of Set 14 | riyadh
# Processing Record 20 of Set 14 | hilton head island
# Processing Record 21 of Set 14 | karatau
# Processing Record 22 of Set 14 | novyy urengoy
# Processing Record 23 of Set 14 | makakilo city
# Processing Record 24 of Set 14 | babanusah
# City not found. Skipping....
# Processing Record 25 of Set 14 | kovdor
# Processing Record 26 of Set 14 | belmonte
# Processing Record 27 of Set 14 | koungou
# Processing Record 28 of Set 14 | uyuni
# Processing Record 29 of Set 14 | vangaindrano
# Processing Record 30 of Set 14 | prince albert
# Processing Record 31 of Set 14 | uray
# Processing Record 32 of Set 14 | dauphin
# Processing Record 33 of Set 14 | quepos
# Processing Record 34 of Set 14 | avera
# Processing Record 35 of Set 14 | onalaska
# Processing Record 36 of Set 14 | witu
# Processing Record 37 of Set 14 | makat
# Processing Record 38 of Set 14 | aberdeen
# Processing Record 39 of Set 14 | hayvoron
# Processing Record 40 of Set 14 | suba
# Processing Record 41 of Set 14 | berezovyy
# Processing Record 42 of Set 14 | moulmeingyun
# City not found. Skipping....
# Processing Record 43 of Set 14 | palana
# Processing Record 44 of Set 14 | gorom-gorom
# Processing Record 45 of Set 14 | lishui
# Processing Record 46 of Set 14 | whitehorse
# Processing Record 47 of Set 14 | villahermosa
# Processing Record 48 of Set 14 | labytnangi
# Processing Record 49 of Set 14 | port keats
# Processing Record 50 of Set 14 | ginda
# Processing Record 1 of Set 15 | oxford
# Processing Record 2 of Set 15 | luganville
# Processing Record 3 of Set 15 | tumannyy
# City not found. Skipping....
# Processing Record 4 of Set 15 | pangoa
# Processing Record 5 of Set 15 | urumita
# Processing Record 6 of Set 15 | newport
# Processing Record 7 of Set 15 | porbandar
# Processing Record 8 of Set 15 | shache
# Processing Record 9 of Set 15 | sajanan
# Processing Record 10 of Set 15 | marquette
# Processing Record 11 of Set 15 | nanning
# Processing Record 12 of Set 15 | penzance
# Processing Record 13 of Set 15 | yanchukan
# City not found. Skipping....
# Processing Record 14 of Set 15 | xuddur
# Processing Record 15 of Set 15 | cizre
# Processing Record 16 of Set 15 | sigiriya
# Processing Record 17 of Set 15 | ust-ilimsk
# Processing Record 18 of Set 15 | urdoma
# Processing Record 19 of Set 15 | necochea
# Processing Record 20 of Set 15 | san antonio
# Processing Record 21 of Set 15 | te anau
# Processing Record 22 of Set 15 | salamiyah
# Processing Record 23 of Set 15 | kloulklubed
# Processing Record 24 of Set 15 | brae
# Processing Record 25 of Set 15 | nzerekore
# Processing Record 26 of Set 15 | mont-de-marsan
# Processing Record 27 of Set 15 | atambua
# Processing Record 28 of Set 15 | khvastovichi
# Processing Record 29 of Set 15 | kuche
# City not found. Skipping....
# Processing Record 30 of Set 15 | ipameri
# Processing Record 31 of Set 15 | shelburne
# Processing Record 32 of Set 15 | pangai
# Processing Record 33 of Set 15 | klaeng
# Processing Record 34 of Set 15 | cabatuan
# Processing Record 35 of Set 15 | mayumba
# Processing Record 36 of Set 15 | lhokseumawe
# Processing Record 37 of Set 15 | constitucion
# Processing Record 38 of Set 15 | lakes entrance
# Processing Record 39 of Set 15 | sorong
# Processing Record 40 of Set 15 | srandakan
# Processing Record 41 of Set 15 | eskisehir
# Processing Record 42 of Set 15 | ketchikan
# Processing Record 43 of Set 15 | mosquera
# Processing Record 44 of Set 15 | ternate
# Processing Record 45 of Set 15 | quelimane
# Processing Record 46 of Set 15 | phonhong
# Processing Record 47 of Set 15 | kurchum
# Processing Record 48 of Set 15 | wenatchee
# Processing Record 49 of Set 15 | morgan city
# Processing Record 50 of Set 15 | macklin
# Processing Record 1 of Set 16 | cagayan de tawi-tawi
# City not found. Skipping....
# Processing Record 2 of Set 16 | iquique
# Processing Record 3 of Set 16 | gibsons
# Processing Record 4 of Set 16 | cap-aux-meules
# Processing Record 5 of Set 16 | smidovich
# Processing Record 6 of Set 16 | kraslava
# Processing Record 7 of Set 16 | makokou
# Processing Record 8 of Set 16 | turayf
# Processing Record 9 of Set 16 | itupiranga
# ----------------------------------
# Data Retrieval Complete...........
# ----------------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Albany  42.6001  -73.9662     45.09        64         100
# 1          Northam  51.0333   -4.2167     45.61        72          14
# 2  Bambous Virieux -20.3428   57.7575     78.22        78          40
# 3            Metro  -5.1131  105.3067     73.60        97         100
# 4     Ponta Do Sol  32.6667  -17.1000     66.70        77          26
# 5          Rikitea -23.1203 -134.9692     76.10        70          23
# 6           Beloha -25.1667   45.0500     75.13        81          52
# 7       Butaritari   3.0707  172.7902     82.11        76         100
# 8           Lodwar   3.1191   35.5973     83.70        44          65
# 9     Puerto Ayora  -0.7393  -90.3518     76.96        92          96
#
#    Wind Speed Country                 Date Current Weather Description
# 0        1.01      US  2021-12-10 18:40:50             overcast clouds
# 1       18.30      GB  2021-12-10 18:40:27                  few clouds
# 2        5.75      MU  2021-12-10 18:31:47            scattered clouds
# 3        7.31      ID  2021-12-10 18:41:27             overcast clouds
# 4        9.78      PT  2021-12-10 18:40:54            scattered clouds
# 5       17.29      PF  2021-12-10 18:40:49                  few clouds
# 6        8.46      MG  2021-12-10 18:36:01               broken clouds
# 7       13.42      KI  2021-12-10 18:41:04                  light rain
# 8       24.27      KE  2021-12-10 18:41:28               broken clouds
# 9        5.01      EC  2021-12-10 18:37:29             overcast clouds

# %%
# Reorder the coulumns.
new_columns_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Weather Description"]
city_data_df[new_columns_order]
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0             Albany      US  42.6001  -73.9662     45.09        64
# 1            Northam      GB  51.0333   -4.2167     45.61        72
# 2    Bambous Virieux      MU -20.3428   57.7575     78.22        78
# 3              Metro      ID  -5.1131  105.3067     73.60        97
# 4       Ponta Do Sol      PT  32.6667  -17.1000     66.70        77
# ..               ...     ...      ...       ...       ...       ...
# 687        Smidovich      RU  48.6000  133.8167     21.29        97
# 688         Kraslava      LV  55.8951   27.1680     35.15        97
# 689          Makokou      GA   0.5738   12.8642     76.91        71
# 690           Turayf      SA  31.6725   38.6637     52.05        66
# 691       Itupiranga      BR  -5.1347  -49.3267     89.92        69
#
#      Cloudiness  Wind Speed Current Weather Description
# 0           100        1.01             overcast clouds
# 1            14       18.30                  few clouds
# 2            40        5.75            scattered clouds
# 3           100        7.31             overcast clouds
# 4            26        9.78            scattered clouds
# ..          ...         ...                         ...
# 687         100        6.93                  light snow
# 688         100       14.85             overcast clouds
# 689          98        1.45             overcast clouds
# 690           0       13.80                   clear sky
# 691          98        2.13             overcast clouds
#
# [692 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
